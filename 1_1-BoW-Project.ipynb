# %%
import numpy as np
import matplotlib.pyplot as plt

import codecs
import re
import os.path

# %% [markdown]
# # Données reconnaissance du locuteur (Chirac/Mitterrand)

# %%
# Chargement des données:
def load_pres(fname):
    alltxts = []
    alllabs = []
    s=codecs.open(fname, 'r','utf-8') # pour régler le codage
    while True:
        txt = s.readline()
        if(len(txt))<5:
            break
        print("tx1t",txt)
        lab = re.sub(r"<[0-9]*:[0-9]*:(.)>.*","\\1",txt)
        print("lab",lab)
        txt = re.sub(r"<[0-9]*:[0-9]*:.>(.*)","\\1",txt)
        print("txt2",txt)
        if lab.count('M') >0:
            alllabs.append(-1)
        else: 
            alllabs.append(1)
        alltxts.append(txt)
    return alltxts,alllabs

# %%
fname = "./datasets/AFDpresidentutf8/corpus.tache1.learn.utf8"
alltxts,alllabs = load_pres(fname)
# Out:
# tx1t <100:1:C> Quand je dis chers amis, il ne s'agit pas là d'une formule diplomatique, mais de l'expression de ce que je ressens.
#
# lab C
#
# txt2  Quand je dis chers amis, il ne s'agit pas là d'une formule diplomatique, mais de l'expression de ce que je ressens.
#
# tx1t <100:2:C> D'abord merci de cet exceptionnel accueil que les Congolais, les Brazavillois, nous ont réservé cet après-midi.
#
# lab C
#
# txt2  D'abord merci de cet exceptionnel accueil que les Congolais, les Brazavillois, nous ont réservé cet après-midi.
#
# tx1t <100:3:C> C'est toujours très émouvant de venir en Afrique car c'est probablement l'une des rares terres du monde où l'on ait conservé cette convivialité, cette amitié, ce respect de l'autre qui s'expriment avec chaleur, avec spontanéité et qui réchauffent le coeur de ceux qui arrivent et de ceux qui reçoivent.
#
# lab C
#
# txt2  C'est toujours très émouvant de venir en Afrique car c'est probablement l'une des rares terres du monde où l'on ait conservé cette convivialité, cette amitié, ce respect de l'autre qui s'expriment avec chaleur, avec spontanéité et qui réchauffent le coeur de ceux qui arrivent et de ceux qui reçoivent.
#
# tx1t <100:4:C> Aucun citoyen français ne peut être indifférent à un séjour à Brazzaville.
#
# lab C
#
# txt2  Aucun citoyen français ne peut être indifférent à un séjour à Brazzaville.
#
# tx1t <100:5:C> Le Congo, que naguère le <nom> qualifia de "refuge pour la liberté", de "base de départ pour la libération", de "môle pour la Résistance", comment ne pas être heureux de s'y retrouver ?
#
# lab C
#
# txt2  Le Congo, que naguère le <nom> qualifia de "refuge pour la liberté", de "base de départ pour la libération", de "môle pour la Résistance", comment ne pas être heureux de s'y retrouver ?
#
# tx1t <100:6:C> Comment ne pas y voir un signe ?
#
# lab C
#
# txt2  Comment ne pas y voir un signe ?
#
# tx1t <100:7:C> Brazzaville n'est pas une capitale ordinaire.
#
# lab C
#
# txt2  Brazzaville n'est pas une capitale ordinaire.
#
# tx1t <100:8:C> Les voies de la libre disposition des peuples et de leur coopération furent explorées il y a un demi siècle, ici, à Brazzaville.
#
# lab C
#
# txt2  Les voies de la libre disposition des peuples et de leur coopération furent explorées il y a un demi siècle, ici, à Brazzaville.
#
# tx1t <100:9:C> C'est à Brazzaville, encore, que quinze années plus tard fut proclamée la Communauté.
#
# lab C
#
# txt2  C'est à Brazzaville, encore, que quinze années plus tard fut proclamée la Communauté.
#
# tx1t <100:10:C> A Brazzaville, que fut scellée la première union régionale des pays africains francophones.
#
# lab C
#
# txt2  A Brazzaville, que fut scellée la première union régionale des pays africains francophones.
#
# tx1t <100:11:C> A Brazzaville, que l'Afrique de demain se dessine.
#
# lab C
#
# txt2  A Brazzaville, que l'Afrique de demain se dessine.
#
# tx1t <100:12:M> Je ne sais ni pourquoi ni comment on s'est opposé il y a quelques douze années - douze ou treize ans - à la création de l'Université technologique.
#
# lab M
#
# txt2  Je ne sais ni pourquoi ni comment on s'est opposé il y a quelques douze années - douze ou treize ans - à la création de l'Université technologique.
#
# tx1t <100:13:M> C'est vrai qu'il y a très souvent dans notre pays un refus de regarder droit devant soi, comme un souhait d'en rester là, une certaine peur du changement, c'est vrai.
#
# lab M
#
# txt2  C'est vrai qu'il y a très souvent dans notre pays un refus de regarder droit devant soi, comme un souhait d'en rester là, une certaine peur du changement, c'est vrai.
#
# tx1t <100:14:M> Et ce sentiment n'est pas également partagé, monsieur le maire, mais enfin il existe de tous côtés.
#
# lab M
#
# txt2  Et ce sentiment n'est pas également partagé, monsieur le maire, mais enfin il existe de tous côtés.
#
# tx1t <100:15:M> Il est vrai que ceux qui possèdent préfèrent que cela ne change pas, et ceux qui n'ont rien préfèrent que cela change.
#
# lab M
#
# txt2  Il est vrai que ceux qui possèdent préfèrent que cela ne change pas, et ceux qui n'ont rien préfèrent que cela change.
#
# tx1t <100:16:M> Moi je suis du côté de ceux qui pensent qu'il vaut mieux répartir plus justement l'effort et le produit de la nation.
#
# lab M
#
# txt2  Moi je suis du côté de ceux qui pensent qu'il vaut mieux répartir plus justement l'effort et le produit de la nation.
#
# tx1t <100:17:M> Mais les esprits, eux, évoluent souvent lentement.
#
# lab M
#
# txt2  Mais les esprits, eux, évoluent souvent lentement.
#
# tx1t <100:18:M> Je m'en plains tous les jours et il m'est agréable d'entendre l'écho de mes pensées, de mes propos, dans votre propre discours.
#
# lab M
#
# txt2  Je m'en plains tous les jours et il m'est agréable d'entendre l'écho de mes pensées, de mes propos, dans votre propre discours.
#
# tx1t <100:19:M> Vous avez évoqué, monsieur le maire, les Présidents de la République qui m'ont précédé.
#
# lab M
#
# txt2  Vous avez évoqué, monsieur le maire, les Présidents de la République qui m'ont précédé.
#
# tx1t <100:20:M> Je suis le sixième.
#
# lab M
#
# txt2  Je suis le sixième.
#
# tx1t <100:21:M> Et puisque nous nous connaissons depuis quelques trente cinq ans, nous avons donc trente cinq ans de plus, vous et moi.
#
# lab M
#
# txt2  Et puisque nous nous connaissons depuis quelques trente cinq ans, nous avons donc trente cinq ans de plus, vous et moi.
#
# tx1t <100:22:M> Vous me paraissez solide au poste, c'est le voeu que je forme pour une bonne santé, vous souhaitez peut-être connaitre un septième Président, eh bien, vous avez le temps d'attendre.
#
# lab M
#
# txt2  Vous me paraissez solide au poste, c'est le voeu que je forme pour une bonne santé, vous souhaitez peut-être connaitre un septième Président, eh bien, vous avez le temps d'attendre.
#
# tx1t <100:23:M> Monsieur le maire, mesdames et messieurs, l'Université technologique a donné le signal, un grand signal.
#
# lab M
#
# txt2  Monsieur le maire, mesdames et messieurs, l'Université technologique a donné le signal, un grand signal.
#
# tx1t <100:24:M> Vous savez que les gouvernements que j'ai constitués ont fixé la recherche parmi l'une des priorités, peut-être même la priorité principale.
#
# lab M
#
# txt2  Vous savez que les gouvernements que j'ai constitués ont fixé la recherche parmi l'une des priorités, peut-être même la priorité principale.
#
# tx1t <100:25:M> Il suffit pour cela de se reporter aux crédits qui ont été consacrés à la recherche et qui ont connu une augmentation considérable, au point que nous pouvons disputer la palme aujourd'hui aux pays les plus évolués du monde.
#
# lab M
#
# txt2  Il suffit pour cela de se reporter aux crédits qui ont été consacrés à la recherche et qui ont connu une augmentation considérable, au point que nous pouvons disputer la palme aujourd'hui aux pays les plus évolués du monde.
#
# tx1t <100:26:M> Quand on pense que si l'on faisait la somme des crédits de recherche consacrés par l'Allemagne de l'Ouest, la Grande-Bretagne, l'Italie et la France on constaterait que nous dépensons plus d'argent pour chercher que ne le font les Japonais ou les Américains, le résultat n'est pas le même non pas que nos chercheurs ne manquent ni de compétence, ni de science, ni d'imagination, leurs résultats sont là.
#
# lab M
#
# txt2  Quand on pense que si l'on faisait la somme des crédits de recherche consacrés par l'Allemagne de l'Ouest, la Grande-Bretagne, l'Italie et la France on constaterait que nous dépensons plus d'argent pour chercher que ne le font les Japonais ou les Américains, le résultat n'est pas le même non pas que nos chercheurs ne manquent ni de compétence, ni de science, ni d'imagination, leurs résultats sont là.
#
# tx1t <100:27:M> La recherche appliquée, elle est en très bonne santé mais à l'application industrielle, c'est là que ce trouve le hiatus pour lequel au cours de ces quinze dernières années le progrès n'est pas suffisant et c'est ce qu'il faut corriger.
#
# lab M
#
# txt2  La recherche appliquée, elle est en très bonne santé mais à l'application industrielle, c'est là que ce trouve le hiatus pour lequel au cours de ces quinze dernières années le progrès n'est pas suffisant et c'est ce qu'il faut corriger.
#
# tx1t <100:28:M> Il faut absolument que la relation soit directe, totalement directe entre la recherche, l'effort de la pensée, l'application par le savoir et la transformation industrielle.
#
# lab M
#
# txt2  Il faut absolument que la relation soit directe, totalement directe entre la recherche, l'effort de la pensée, l'application par le savoir et la transformation industrielle.
#
# tx1t <100:29:C> Aussi, votre hospitalité, la vôtre et celle de la nation congolaise, me touchent particulièrement.
#
# lab C
#
# txt2  Aussi, votre hospitalité, la vôtre et celle de la nation congolaise, me touchent particulièrement.
#
# tx1t <100:30:C> Le Congo et la France ont su nouer des liens particuliers dans les épreuves.
#
# lab C
#
# txt2  Le Congo et la France ont su nouer des liens particuliers dans les épreuves.
#
# tx1t <100:31:C> A l'heure où le monde change, où l'Afrique se cherche, où l'espoir renaît ici, où d'alarmantes secousses grondent un peu plus loin, il faut rester fidèle à cette relation.
#
# lab C
#
# txt2  A l'heure où le monde change, où l'Afrique se cherche, où l'espoir renaît ici, où d'alarmantes secousses grondent un peu plus loin, il faut rester fidèle à cette relation.
#
# tx1t <100:32:C> Au nom de cette relation, j'ai plaidé à Lyon, lors du sommet du G7, pour un nouveau partenariat entre les pays en développement, les pays développés et les institutions multilatérales.
#
# lab C
#
# txt2  Au nom de cette relation, j'ai plaidé à Lyon, lors du sommet du G7, pour un nouveau partenariat entre les pays en développement, les pays développés et les institutions multilatérales.
#
# tx1t <100:33:C> La voix de la France a été entendue.
#
# lab C
#
# txt2  La voix de la France a été entendue.
#
# tx1t <100:34:C> J'ai notamment obtenu que les ressources de l'aide publique au développement soient concentrées en priorité sur les pays les plus pauvres, en particulier ceux d'Afrique.
#
# lab C
#
# txt2  J'ai notamment obtenu que les ressources de l'aide publique au développement soient concentrées en priorité sur les pays les plus pauvres, en particulier ceux d'Afrique.
#
# tx1t <100:35:C> Ainsi, l'horizon s'éclaircit.
#
# lab C
#
# txt2  Ainsi, l'horizon s'éclaircit.
#
# tx1t <100:36:C> L'avenir appartient à l'Afrique, pourvu qu'elle s'en saisisse.
#
# lab C
#
# txt2  L'avenir appartient à l'Afrique, pourvu qu'elle s'en saisisse.
#
# tx1t <100:37:C> L'avenir appartient au Congo.
#
# lab C
#
# txt2  L'avenir appartient au Congo.
#
# tx1t <100:38:C> Il saura, j'en suis sûr, le préparer.
#
# lab C
#
# txt2  Il saura, j'en suis sûr, le préparer.
#
# tx1t <100:39:C> Je lève mon verre en l'honneur du <nom> , Président de la République du Congo, en l'honneur de <nom> , en l'honneur du Congo ami de la France.
#
# lab C
#
# txt2  Je lève mon verre en l'honneur du <nom> , Président de la République du Congo, en l'honneur de <nom> , en l'honneur du Congo ami de la France.
#
# tx1t <101:1:C> Je voudrais d'abord saluer le Président du gouvernement de Polynésie Française, <nom> , son épouse Tanita, et la délégation qui l'accompagne et qui sont pour moi des amis pour qui j'ai beaucoup d'estime et je dirais d'affection.
#
# lab C
#
# txt2  Je voudrais d'abord saluer le Président du gouvernement de Polynésie Française, <nom> , son épouse Tanita, et la délégation qui l'accompagne et qui sont pour moi des amis pour qui j'ai beaucoup d'estime et je dirais d'affection.
#
# tx1t <101:2:C> Je voudrais saluer les polynésiens présents dans cette salle et surtout les personnalités japonaises qui ont répondu à l'invitation du <nom> et qui marque ainsi leur intérêt à promouvoir, à renforcer, à initier des relations fortes entre ce superbe pays qui est la Polynésie Française, une terre de France dans le Pacifique Sud et le Japon.
#
# lab C
#
# txt2  Je voudrais saluer les polynésiens présents dans cette salle et surtout les personnalités japonaises qui ont répondu à l'invitation du <nom> et qui marque ainsi leur intérêt à promouvoir, à renforcer, à initier des relations fortes entre ce superbe pays qui est la Polynésie Française, une terre de France dans le Pacifique Sud et le Japon.
#
# tx1t <101:3:C> C'est vrai qu'il y a là des liens naturelles.
#
# lab C
#
# txt2  C'est vrai qu'il y a là des liens naturelles.
#
# tx1t <101:4:C> Nous avons engagés déjà depuis quelques temps, une action déterminée de renforcement des liens entre la France et le Japon.
#
# lab C
#
# txt2  Nous avons engagés déjà depuis quelques temps, une action déterminée de renforcement des liens entre la France et le Japon.
#
# tx1t <101:5:C> Nous avons pris un certains nombre de décisions avec le Premier <nom> pour renforcer cette action et ceci, je le répète, avec une grande volonté de faire progresser les choses, le dialogue politique et culturelle bien sûr, mais aussi et peut-être surtout -car les premiers étaient déjà bon- nos échanges commerciaux, industriels, économiques.
#
# lab C
#
# txt2  Nous avons pris un certains nombre de décisions avec le Premier <nom> pour renforcer cette action et ceci, je le répète, avec une grande volonté de faire progresser les choses, le dialogue politique et culturelle bien sûr, mais aussi et peut-être surtout -car les premiers étaient déjà bon- nos échanges commerciaux, industriels, économiques.
#
# tx1t <101:6:C> Or, la France c'est naturellement notre exagone européen avec toutes ses capacités, son art de vivre, sa haute technologie, son industrie puissante, sa capacité d'exporter, la France est un des premiers exportateurs du monde et même le deuxième par tête d'habitant, avant le Japon.
#
# lab C
#
# txt2  Or, la France c'est naturellement notre exagone européen avec toutes ses capacités, son art de vivre, sa haute technologie, son industrie puissante, sa capacité d'exporter, la France est un des premiers exportateurs du monde et même le deuxième par tête d'habitant, avant le Japon.
#
# tx1t <101:7:C> C'est dire que nous avons la compétence de le faire mais la France n'est pas réduite à l'espace européen.
#
# lab C
#
# txt2  C'est dire que nous avons la compétence de le faire mais la France n'est pas réduite à l'espace européen.
#
# tx1t <101:8:C> La France est présente un peu partout sur la planète.
#
# lab C
#
# txt2  La France est présente un peu partout sur la planète.
#
# tx1t <101:9:C> Elle l'est en Amérique du sud, dans la Caraïbe, aux Antilles, elle l'est dans l'Océan Indien, avec la Réunion, avec Mayotte et elle l'est dans le Pacifique Sud, avec la Calédonie avec Wallis et Futuna et puis bien sûr avec la Polynésie.
#
# lab C
#
# txt2  Elle l'est en Amérique du sud, dans la Caraïbe, aux Antilles, elle l'est dans l'Océan Indien, avec la Réunion, avec Mayotte et elle l'est dans le Pacifique Sud, avec la Calédonie avec Wallis et Futuna et puis bien sûr avec la Polynésie.
#
# tx1t <101:10:C> La Polynésie qui a engagé sous l'autorité de son Président, une action déterminée pour maintenir son acquis économique et sociale qui est déjà très important.
#
# lab C
#
# txt2  La Polynésie qui a engagé sous l'autorité de son Président, une action déterminée pour maintenir son acquis économique et sociale qui est déjà très important.
#
# tx1t <101:11:C> La Polynésie est l'un des Territoires du Pacifique où la richesse par tête d'habitant est le plus élevé, mais également pour améliorer encore sa capacité de développement, et ceci suppose bien sûr des liens son environnement, des liens qui se renforcent sans cesse avec son environnement la Polynésie a de fortes capacités.
#
# lab C
#
# txt2  La Polynésie est l'un des Territoires du Pacifique où la richesse par tête d'habitant est le plus élevé, mais également pour améliorer encore sa capacité de développement, et ceci suppose bien sûr des liens son environnement, des liens qui se renforcent sans cesse avec son environnement la Polynésie a de fortes capacités.
#
# tx1t <101:12:C> Elle a d'abord, il faut le dire, un environnement, des sites, un climat tout à fait exceptionnelle et qui naturellement suggère le tourisme.
#
# lab C
#
# txt2  Elle a d'abord, il faut le dire, un environnement, des sites, un climat tout à fait exceptionnelle et qui naturellement suggère le tourisme.
#
# tx1t <101:13:C> On vient du monde entier en Polynésie où l'accueil, les capacités hôtelières, les sites sont tout à fait remarquables.
#
# lab C
#
# txt2  On vient du monde entier en Polynésie où l'accueil, les capacités hôtelières, les sites sont tout à fait remarquables.
#
# tx1t <101:14:C> Et on doit venir du Japon.
#
# lab C
#
# txt2  Et on doit venir du Japon.
#
# tx1t <101:15:C> Il y a naturellement une certaine distance, une dizaine d'heures de vol, mais c'est un peu le paradis terrestre pour le touriste, d'où qu'il vienne.
#
# lab C
#
# txt2  Il y a naturellement une certaine distance, une dizaine d'heures de vol, mais c'est un peu le paradis terrestre pour le touriste, d'où qu'il vienne.
#
# tx1t <101:16:C> Je ne saurais trop engagé ceux qui ici s'occupent d'organiser le développement du tourisme, d'organiser les transports, de jouer cette carte polynésienne, il ne regretteront pas.
#
# lab C
#
# txt2  Je ne saurais trop engagé ceux qui ici s'occupent d'organiser le développement du tourisme, d'organiser les transports, de jouer cette carte polynésienne, il ne regretteront pas.
#
# tx1t <101:17:M> Vous savez aussi qu'un homme politique c'est un usager assez assidu des grandes lignes et même des petites car il faut bien aller un peu partout, de la capitale à sa circonscription et quand je pense au temps que j'ai passé sur la ligne Paris-Nevers, je ne peux pas être de ceux qui sous-estiment l'importance de la durée d'un trajet, de son confort, de la fréquence des liaisons ou de la ponctualité des trains.
#
# lab M
#
# txt2  Vous savez aussi qu'un homme politique c'est un usager assez assidu des grandes lignes et même des petites car il faut bien aller un peu partout, de la capitale à sa circonscription et quand je pense au temps que j'ai passé sur la ligne Paris-Nevers, je ne peux pas être de ceux qui sous-estiment l'importance de la durée d'un trajet, de son confort, de la fréquence des liaisons ou de la ponctualité des trains.
#
# tx1t <101:18:M> Bref, je suis un usager particulièrement compétent.
#
# lab M
#
# txt2  Bref, je suis un usager particulièrement compétent.
#
# tx1t <101:19:M> Je me souviens de ces périodes où, parlementaire pendant trente-cinq ans du département de la Nièvre et ne laissant jamais passer une semaine, sans me rendre à ma mairie, je traversais de part en part la France, de Bordeaux à Saint-Germain des Fossés ou à Gannat pour remonter jusqu'à Nevers, ce qui à l'époque, permettez-moi de vous le dire, monsieur le Président, représentait des heures et des heures, surtout sur cette ligne transversale qui ne disposait pas d'un très grand confort.
#
# lab M
#
# txt2  Je me souviens de ces périodes où, parlementaire pendant trente-cinq ans du département de la Nièvre et ne laissant jamais passer une semaine, sans me rendre à ma mairie, je traversais de part en part la France, de Bordeaux à Saint-Germain des Fossés ou à Gannat pour remonter jusqu'à Nevers, ce qui à l'époque, permettez-moi de vous le dire, monsieur le Président, représentait des heures et des heures, surtout sur cette ligne transversale qui ne disposait pas d'un très grand confort.
#
# tx1t <101:20:M> Je ne suis pas sûr, bien que j'aie cessé de faire la ligne depuis quelque temps, que cela ait tellement changé.
#
# lab M
#
# txt2  Je ne suis pas sûr, bien que j'aie cessé de faire la ligne depuis quelque temps, que cela ait tellement changé.
#
# tx1t <101:21:M> Alors songeons à ceux qui continuent d'aller de gare en gare, d'y trouver à cinq heures du matin des petits lumignons bleus tandis que s'ouvre en baillant le Café de la Gare, tandis que les croissants du matin ne sont pas encore arrivés et qu'il reste ceux de la veille ou de l'avant-veille, c'est cela la mentalité de l'usager que j'ai avec une extrême constance pratiquée pendant la moitié de ma vie.
#
# lab M
#
# txt2  Alors songeons à ceux qui continuent d'aller de gare en gare, d'y trouver à cinq heures du matin des petits lumignons bleus tandis que s'ouvre en baillant le Café de la Gare, tandis que les croissants du matin ne sont pas encore arrivés et qu'il reste ceux de la veille ou de l'avant-veille, c'est cela la mentalité de l'usager que j'ai avec une extrême constance pratiquée pendant la moitié de ma vie.
#
# tx1t <101:22:M> Je suis un peu exempté aujourd'hui de ce genre d'épreuves mais je suis bien obligé de penser aux autres qui ne connaissent pas tous les facilités que je connais moi-même aujourd'hui.
#
# lab M
#
# txt2  Je suis un peu exempté aujourd'hui de ce genre d'épreuves mais je suis bien obligé de penser aux autres qui ne connaissent pas tous les facilités que je connais moi-même aujourd'hui.
#
# tx1t <101:23:M> Alors, j'étais assez disposé à comprendre l'utilité d'un autre progrès sur cette fameuse ligne Paris Clermont-Ferrand en passant par Nevers et Moulins.
#
# lab M
#
# txt2  Alors, j'étais assez disposé à comprendre l'utilité d'un autre progrès sur cette fameuse ligne Paris Clermont-Ferrand en passant par Nevers et Moulins.
#
# tx1t <101:24:M> Cette électrification est un événement important pour les régions traversées, c'est aussi un élément de désenclavement du Massif Central, ce n'est pas le seul, mais il n'est pas négligeable.
#
# lab M
#
# txt2  Cette électrification est un événement important pour les régions traversées, c'est aussi un élément de désenclavement du Massif Central, ce n'est pas le seul, mais il n'est pas négligeable.
#
# tx1t <101:25:M> Il y a déjà l'autoroute, mais l'autoroute fait un détour par Bourges et par Montluçon, et peut-être pas très loin de Gannat avant d'arriver à Clermont-Ferrand.
#
# lab M
#
# txt2  Il y a déjà l'autoroute, mais l'autoroute fait un détour par Bourges et par Montluçon, et peut-être pas très loin de Gannat avant d'arriver à Clermont-Ferrand.
#
# tx1t <101:26:M> Puisque la route passait par là, il fallait bien que le train passe par ici, et qu'il pût y passer dans des conditions agréables et faciles pour les habitants de ces régions ou pour ceux qui font le va-et-vient pour leur travail entre les capitales de région ou de département et la capitale de la France.
#
# lab M
#
# txt2  Puisque la route passait par là, il fallait bien que le train passe par ici, et qu'il pût y passer dans des conditions agréables et faciles pour les habitants de ces régions ou pour ceux qui font le va-et-vient pour leur travail entre les capitales de région ou de département et la capitale de la France.
#
# tx1t <101:27:M> Je peux le dire, je tire peu de vanité, croyez-moi, des décisions qu'il m'arrive de prendre mais celle-là, j'y tiens.
#
# lab M
#
# txt2  Je peux le dire, je tire peu de vanité, croyez-moi, des décisions qu'il m'arrive de prendre mais celle-là, j'y tiens.
#
# tx1t <101:28:M> J'y tiens parce que cela a été le résultat d'un long combat - on ne peut pas dire que ma proposition d'électrification pour cette ligne ait reçu l'accueil le plus enthousiaste et de la SNCF et des autorités du moment - et même avec le gouvernement que je présidais, parce que c'est le centre de la France, parce qu'il y a les grandes voies de communication qui passent par la vallée du Rhône, d'une part, ou bien les grandes communications avec l'Espagne qui passent par l'Ouest de la France, parce que le Nord est mitoyen de pays étrangers, parce que, parce que... Eh bien ! oui, il fallait bien que cette région du centre pût être desservie avec des moyens modernes.
#
# lab M
#
# txt2  J'y tiens parce que cela a été le résultat d'un long combat - on ne peut pas dire que ma proposition d'électrification pour cette ligne ait reçu l'accueil le plus enthousiaste et de la SNCF et des autorités du moment - et même avec le gouvernement que je présidais, parce que c'est le centre de la France, parce qu'il y a les grandes voies de communication qui passent par la vallée du Rhône, d'une part, ou bien les grandes communications avec l'Espagne qui passent par l'Ouest de la France, parce que le Nord est mitoyen de pays étrangers, parce que, parce que... Eh bien ! oui, il fallait bien que cette région du centre pût être desservie avec des moyens modernes.
#
# tx1t <101:29:M> Vous l'avez fait et je vous en remercie.
#
# lab M
#
# txt2  Vous l'avez fait et je vous en remercie.
#
# tx1t <101:30:M> Et puis venir à Clermont-Ferrand, de cette façon, c'est quand même une commodité nécessaire, c'est une ville très importante que celle-ci, quand on pense à sa capacité industrielle, à cette capitale mondiale du pneumatique, avec ses hommes qui savent se battre dans une compétition dure et qui la gagnent.
#
# lab M
#
# txt2  Et puis venir à Clermont-Ferrand, de cette façon, c'est quand même une commodité nécessaire, c'est une ville très importante que celle-ci, quand on pense à sa capacité industrielle, à cette capitale mondiale du pneumatique, avec ses hommes qui savent se battre dans une compétition dure et qui la gagnent.
#
# tx1t <101:31:M> Une ville, où il y a beaucoup de talents de toutes sortes, et ce, depuis des siècles ; une ville où l'on a su aborder les questions de logement, réussir la rénovation d'un centre ancien.
#
# lab M
#
# txt2  Une ville, où il y a beaucoup de talents de toutes sortes, et ce, depuis des siècles ; une ville où l'on a su aborder les questions de logement, réussir la rénovation d'un centre ancien.
#
# tx1t <101:32:C> J'ajoute que l'industrie hôtelière dans cette région est une industrie performante et qui améliore, je dirais chaque jour, les prestations qu'elle offre à ces clients.
#
# lab C
#
# txt2  J'ajoute que l'industrie hôtelière dans cette région est une industrie performante et qui améliore, je dirais chaque jour, les prestations qu'elle offre à ces clients.
#
# tx1t <101:33:C> Puis, il y a bien entendu sa richesse aliotique, ses poissons qui peuvent être exportés.
#
# lab C
#
# txt2  Puis, il y a bien entendu sa richesse aliotique, ses poissons qui peuvent être exportés.
#
# tx1t <101:34:C> Nous avons discuté d'ailleurs, le Ministre des Finances a discuté avec son homologue où plus exactement avec le Ministre Japonais, Dumiti, dans le cadre de l'accord que nous a donné le gouvernement japonais pour donner à la Polynésie Française le système de préférence, généraliser, ce qui facilitera ses échanges avec le Japon.
#
# lab C
#
# txt2  Nous avons discuté d'ailleurs, le Ministre des Finances a discuté avec son homologue où plus exactement avec le Ministre Japonais, Dumiti, dans le cadre de l'accord que nous a donné le gouvernement japonais pour donner à la Polynésie Française le système de préférence, généraliser, ce qui facilitera ses échanges avec le Japon.
#
# tx1t <101:35:C> Nous avons beaucoup insisté sur l'importance qu'il y avait à autoriser, à permettre, à susciter les exportations de Polynésie.
#
# lab C
#
# txt2  Nous avons beaucoup insisté sur l'importance qu'il y avait à autoriser, à permettre, à susciter les exportations de Polynésie.
#
# tx1t <101:36:C> Des exportations de poissons de Polynésie vers le Japon.
#
# lab C
#
# txt2  Des exportations de poissons de Polynésie vers le Japon.
#
# tx1t <101:37:C> Et puis enfin, il y a cette richesse que l'on ne trouve qu'en Polynésie et qui n'existe nul par ailleurs dans le monde et qui est la perliculture.
#
# lab C
#
# txt2  Et puis enfin, il y a cette richesse que l'on ne trouve qu'en Polynésie et qui n'existe nul par ailleurs dans le monde et qui est la perliculture.
#
# tx1t <101:38:C> Une perliculture qui porte très très haut le niveau de l'excellence en matière de beauté.
#
# lab C
#
# txt2  Une perliculture qui porte très très haut le niveau de l'excellence en matière de beauté.
#
# tx1t <101:39:C> Je sais que les ventes de perles au Japon qui représentent pour la Polynésie un revenu important, substantiel, croisse sans cesse et je m'en réjouis.
#
# lab C
#
# txt2  Je sais que les ventes de perles au Japon qui représentent pour la Polynésie un revenu important, substantiel, croisse sans cesse et je m'en réjouis.
#
# tx1t <101:40:C> Et bien, je dirais quelque chose de naturel à marier la perle blanche dont le Japon est le représentant le plus éminent et la perle noire de Tahiti.
#
# lab C
#
# txt2  Et bien, je dirais quelque chose de naturel à marier la perle blanche dont le Japon est le représentant le plus éminent et la perle noire de Tahiti.
#
# tx1t <101:41:C> C'est pourquoi je souhaite que les efforts qui sont faits pour la promotion de ce produit de grand luxe soient couronnés de succès.
#
# lab C
#
# txt2  C'est pourquoi je souhaite que les efforts qui sont faits pour la promotion de ce produit de grand luxe soient couronnés de succès.
#
# tx1t <101:42:C> Et je remercie ceux qui en Polynésie s'y consacrent.
#
# lab C
#
# txt2  Et je remercie ceux qui en Polynésie s'y consacrent.
#
# tx1t <101:43:C> Je souhaite, mon Cher Président, Mon Cher Gaston, je souhaite que les efforts engagés par les autorités Polynésiennes pour le développement du travail, de l'activité économique, des revenus, de la richesse, soient étant un objectif prioritaires de l'action de ces autorités, couronné de succès, s'agissant des échanges avec le Japon.
#
# lab C
#
# txt2  Je souhaite, mon Cher Président, Mon Cher Gaston, je souhaite que les efforts engagés par les autorités Polynésiennes pour le développement du travail, de l'activité économique, des revenus, de la richesse, soient étant un objectif prioritaires de l'action de ces autorités, couronné de succès, s'agissant des échanges avec le Japon.
#
# tx1t <101:44:C> Voilà pourquoi j'ai tenu à vous le dire en tant que Président de la République Française, dont la Polynésie est un élément, j'ai tenu à vous dire que j'appréciais, que je remerciais les efforts que chacune et chacun d'entre vous font dans ce domaine et que je faisais confiance au dynamisme et à la qualité des polynésiens pour accroître sans cesse leurs relations avec le Japon.
#
# lab C
#
# txt2  Voilà pourquoi j'ai tenu à vous le dire en tant que Président de la République Française, dont la Polynésie est un élément, j'ai tenu à vous dire que j'appréciais, que je remerciais les efforts que chacune et chacun d'entre vous font dans ce domaine et que je faisais confiance au dynamisme et à la qualité des polynésiens pour accroître sans cesse leurs relations avec le Japon.
#
# tx1t <102:1:C> Les Américains et les Anglais ont décidé d'arrêter leurs frappes sur l'Irak et je m'en réjouis.
#
# lab C
#
# txt2  Les Américains et les Anglais ont décidé d'arrêter leurs frappes sur l'Irak et je m'en réjouis.
#
# tx1t <102:2:C> Mais naturellement les problèmes demeurent.
#
# lab C
#
# txt2  Mais naturellement les problèmes demeurent.
#
# tx1t <102:3:C> Nous entrons maintenant dans une nouvelle phase, une phase d'élaboration et de mise en oeuvre d'une véritable sortie de crise.
#
# lab C
#
# txt2  Nous entrons maintenant dans une nouvelle phase, une phase d'élaboration et de mise en oeuvre d'une véritable sortie de crise.
#
# tx1t <102:4:C> Et la France y consacrera toute son énergie.
#
# lab C
#
# txt2  Et la France y consacrera toute son énergie.
#
# tx1t <102:5:C> Pour nous la solution des problèmes suppose que la relation entre l'Irak et les Nations Unies soit profondément revue.
#
# lab C
#
# txt2  Pour nous la solution des problèmes suppose que la relation entre l'Irak et les Nations Unies soit profondément revue.
#
# tx1t <102:6:C> - D'abord il faut améliorer les conditions de vie des Irakiens qui souffrent depuis tant d'années.
#
# lab C
#
# txt2  - D'abord il faut améliorer les conditions de vie des Irakiens qui souffrent depuis tant d'années.
#
# tx1t <102:7:C> C'est possible, c'est nécessaire, il faut le faire très vite.
#
# lab C
#
# txt2  C'est possible, c'est nécessaire, il faut le faire très vite.
#
# tx1t <102:8:C> Et la France a dans ce domaine un certain nombre de propositions à faire à ses partenaires.
#
# lab C
#
# txt2  Et la France a dans ce domaine un certain nombre de propositions à faire à ses partenaires.
#
# tx1t <102:9:C> - Mais il ne faut pas relâcher notre vigilance.
#
# lab C
#
# txt2  - Mais il ne faut pas relâcher notre vigilance.
#
# tx1t <102:10:C> La communauté internationale doit pouvoir exercer un contrôle efficace sur les armements irakiens et leurs éventuels développements.
#
# lab C
#
# txt2  La communauté internationale doit pouvoir exercer un contrôle efficace sur les armements irakiens et leurs éventuels développements.
#
# tx1t <102:11:C> Mais cela suppose une nouvelle organisation, une nouvelle méthode.
#
# lab C
#
# txt2  Mais cela suppose une nouvelle organisation, une nouvelle méthode.
#
# tx1t <102:12:C> Et là encore, la France à des propositions à soumettre à ses partenaires.
#
# lab C
#
# txt2  Et là encore, la France à des propositions à soumettre à ses partenaires.
#
# tx1t <102:13:M> Après tout, la famille, vous le savez comme moi, c'est un réseau aussi de solidarité entre les générations.
#
# lab M
#
# txt2  Après tout, la famille, vous le savez comme moi, c'est un réseau aussi de solidarité entre les générations.
#
# tx1t <102:14:M> Le lien entre les enfants et les parents, le lien qui unit, comme je le disais tout à l'heure, les personnes actives et les personnes âgées, c'est lui qui fonde la famille.
#
# lab M
#
# txt2  Le lien entre les enfants et les parents, le lien qui unit, comme je le disais tout à l'heure, les personnes actives et les personnes âgées, c'est lui qui fonde la famille.
#
# tx1t <102:15:M> Je crois que plus qu'hier, ce lien est aujourd'hui désiré.
#
# lab M
#
# txt2  Je crois que plus qu'hier, ce lien est aujourd'hui désiré.
#
# tx1t <102:16:M> Cela tient naturellement aux conditions générales d'existence dans la mesure où s'éloignent de nous les périls les plus profondément ressentis par une espèce humaine traumatisée par deux guerres mondiales et qui a longtemps redouté une catastrophe nouvelle.
#
# lab M
#
# txt2  Cela tient naturellement aux conditions générales d'existence dans la mesure où s'éloignent de nous les périls les plus profondément ressentis par une espèce humaine traumatisée par deux guerres mondiales et qui a longtemps redouté une catastrophe nouvelle.
#
# tx1t <102:17:M> Le lien entre parents et enfants a beaucoup évolué, précisément depuis la dernière guerre mondiale.
#
# lab M
#
# txt2  Le lien entre parents et enfants a beaucoup évolué, précisément depuis la dernière guerre mondiale.
#
# tx1t <102:18:M> L'enfant est reconnu comme un membre essentiel de la famille.
#
# lab M
#
# txt2  L'enfant est reconnu comme un membre essentiel de la famille.
#
# tx1t <102:19:M> Cette place faite à l'enfant, elle va trouver un moyen de s'exprimer grâce à l'approbation par les Nations unies de la Convention internationale des droits de l'enfant.
#
# lab M
#
# txt2  Cette place faite à l'enfant, elle va trouver un moyen de s'exprimer grâce à l'approbation par les Nations unies de la Convention internationale des droits de l'enfant.
#
# tx1t <102:20:M> Il aura fallu dix ans pour que ce projet aboutisse.
#
# lab M
#
# txt2  Il aura fallu dix ans pour que ce projet aboutisse.
#
# tx1t <102:21:M> Les Français ont joué pendant toutes ces années un rôle déterminant pour qu'avance cette idée.
#
# lab M
#
# txt2  Les Français ont joué pendant toutes ces années un rôle déterminant pour qu'avance cette idée.
#
# tx1t <102:22:M> Les mouvements familiaux que vous êtes en ont été les acteurs véritables, les acteurs reconnus, les acteurs indispensables.
#
# lab M
#
# txt2  Les mouvements familiaux que vous êtes en ont été les acteurs véritables, les acteurs reconnus, les acteurs indispensables.
#
# tx1t <102:23:M> Je souhaite que la France en soit l'un des premiers pays signataires et que les travaux d'adaptation de notre droit interne soient menés à bien.
#
# lab M
#
# txt2  Je souhaite que la France en soit l'un des premiers pays signataires et que les travaux d'adaptation de notre droit interne soient menés à bien.
#
# tx1t <102:24:M> C'est ce que les ministres responsables sont aujourd'hui en train de faire en liaison, bien entendu, avec le garde des Sceaux.
#
# lab M
#
# txt2  C'est ce que les ministres responsables sont aujourd'hui en train de faire en liaison, bien entendu, avec le garde des Sceaux.
#
# tx1t <102:25:M> C'est difficile souvent d'adapter un droit interne qui représente toutes nos traditions, nos façons de penser, à un nouveau droit international.
#
# lab M
#
# txt2  C'est difficile souvent d'adapter un droit interne qui représente toutes nos traditions, nos façons de penser, à un nouveau droit international.
#
# tx1t <102:26:M> Mais comme la France est à l'origine de la plupart de ces mutations du droit interne dans le sens de la défense des droits de tous et des droits de l'enfant, cela nous sera plus facile qu'à d'autres.
#
# lab M
#
# txt2  Mais comme la France est à l'origine de la plupart de ces mutations du droit interne dans le sens de la défense des droits de tous et des droits de l'enfant, cela nous sera plus facile qu'à d'autres.
#
# tx1t <102:27:M> Si c'est difficile, il faudra le faire quand même.
#
# lab M
#
# txt2  Si c'est difficile, il faudra le faire quand même.
#
# tx1t <102:28:M> Plus généralement, il faut repenser le statut juridique de l'enfant.
#
# lab M
#
# txt2  Plus généralement, il faut repenser le statut juridique de l'enfant.
#
# tx1t <102:29:M> Songez que la femme mariée a eu beaucoup de peine à acquérir un statut juridique conforme à l'idée que nous nous faisons des rapports entre les femmes et les hommes.
#
# lab M
#
# txt2  Songez que la femme mariée a eu beaucoup de peine à acquérir un statut juridique conforme à l'idée que nous nous faisons des rapports entre les femmes et les hommes.
#
# tx1t <102:30:M> De la même façon, l'enfant doit être respecté pour lui-même.
#
# lab M
#
# txt2  De la même façon, l'enfant doit être respecté pour lui-même.
#
# tx1t <102:31:M> Une limite aux droits à reconnaître aux enfants existe cependant, c'est qu'il ne faut pas leur faire assumer plus qu'ils ne peuvent.
#
# lab M
#
# txt2  Une limite aux droits à reconnaître aux enfants existe cependant, c'est qu'il ne faut pas leur faire assumer plus qu'ils ne peuvent.
#
# tx1t <102:32:M> Un nouveau statut juridique.
#
# lab M
#
# txt2  Un nouveau statut juridique.
#
# tx1t <102:33:M> Oui ! Mais il ne faut pas que pour autant, cela prive l'enfant de la protection à laquelle il a droit et qui dans certains cas doit être renforcée.
#
# lab M
#
# txt2  Oui ! Mais il ne faut pas que pour autant, cela prive l'enfant de la protection à laquelle il a droit et qui dans certains cas doit être renforcée.
#
# tx1t <102:34:M> Comment ne pas penser aux mauvais traitements dont tant d'entre eux sont hélas les victimes.
#
# lab M
#
# txt2  Comment ne pas penser aux mauvais traitements dont tant d'entre eux sont hélas les victimes.
#
# tx1t <102:35:C> - Il faudra enfin évoquer le problème de l'embargo pétrolier, problème politiquement délicat.
#
# lab C
#
# txt2  - Il faudra enfin évoquer le problème de l'embargo pétrolier, problème politiquement délicat.
#
# tx1t <102:36:C> Et dans la mesure où une décision positive serait prise, cela supposerait naturellement un contrôle effectif des armements mais aussi un contrôle très strict de l'utilisation des recettes que l'Irak tirerait de ses ventes de pétrole.
#
# lab C
#
# txt2  Et dans la mesure où une décision positive serait prise, cela supposerait naturellement un contrôle effectif des armements mais aussi un contrôle très strict de l'utilisation des recettes que l'Irak tirerait de ses ventes de pétrole.
#
# tx1t <102:37:C> Pour faire progresser les choses, j'ai eu, ces derniers jours, de nombreux échanges de vues avec les principaux responsables : le secrétaire général de l'ONU, bien sûr, mais aussi les Présidents américain et russe, le Premier ministre britannique, les principaux responsables des pays arabes.
#
# lab C
#
# txt2  Pour faire progresser les choses, j'ai eu, ces derniers jours, de nombreux échanges de vues avec les principaux responsables : le secrétaire général de l'ONU, bien sûr, mais aussi les Présidents américain et russe, le Premier ministre britannique, les principaux responsables des pays arabes.
#
# tx1t <102:38:C> La France est donc prête à apporter une contribution importante, positive à la nécessaire sortie de crise.
#
# lab C
#
# txt2  La France est donc prête à apporter une contribution importante, positive à la nécessaire sortie de crise.
#
# tx1t <102:39:C> Les efforts de tous dans le monde doivent y concourir.
#
# lab C
#
# txt2  Les efforts de tous dans le monde doivent y concourir.
#
# tx1t <103:1:C> C'est, pour mon épouse et moi-même, une grande joie d'accueillir ce soir, à la Résidence de France, les représentants de la communauté française du Maroc.
#
# lab C
#
# txt2  C'est, pour mon épouse et moi-même, une grande joie d'accueillir ce soir, à la Résidence de France, les représentants de la communauté française du Maroc.
#
# tx1t <103:2:C> Nous sommes réunis ce soir à l'occasion du voyage que J'entreprends en Afrique, et qui me conduira, après Rabat, dans trois autres capitales africaines où je rencontrerai la plupart des chefs d'Etat de cette région qui nous tient tant à coeur.
#
# lab C
#
# txt2  Nous sommes réunis ce soir à l'occasion du voyage que J'entreprends en Afrique, et qui me conduira, après Rabat, dans trois autres capitales africaines où je rencontrerai la plupart des chefs d'Etat de cette région qui nous tient tant à coeur.
#
# tx1t <103:3:C> Si j'ai souhaité commencer ce voyage par le Maroc, c'est en raison du caractère exceptionnel des liens qui l'unissent à la France et aussi parce que, comme vous, je porte un profond sentiment d'affection personnelle à ce pays et à son Souverain.
#
# lab C
#
# txt2  Si j'ai souhaité commencer ce voyage par le Maroc, c'est en raison du caractère exceptionnel des liens qui l'unissent à la France et aussi parce que, comme vous, je porte un profond sentiment d'affection personnelle à ce pays et à son Souverain.
#
# tx1t <103:4:C> Mon souhait, par ce voyage, est de marquer ma volonté de donner une impulsion nouvelle aux relations franco-marocaines, et de tourner ainsi définitivement la page des mésententes et des malentendus, désormais révolus, qui ont parfois altéré les rapports entre nos deux pays et dont vous avez été les témoins involontaires.
#
# lab C
#
# txt2  Mon souhait, par ce voyage, est de marquer ma volonté de donner une impulsion nouvelle aux relations franco-marocaines, et de tourner ainsi définitivement la page des mésententes et des malentendus, désormais révolus, qui ont parfois altéré les rapports entre nos deux pays et dont vous avez été les témoins involontaires.
#
# tx1t <103:5:C> Une grande intimité s'est manifestée tout au long de mon séjour ici depuis hier, en particulier lors de nos conversations avec le Roi du Maroc, ainsi qu'avec les membres de son gouvernement et les représentants de la société civile.
#
# lab C
#
# txt2  Une grande intimité s'est manifestée tout au long de mon séjour ici depuis hier, en particulier lors de nos conversations avec le Roi du Maroc, ainsi qu'avec les membres de son gouvernement et les représentants de la société civile.
#
# tx1t <103:6:C> Les Marocains ont également marqué leur amitié en se manifestant, nombreux, lors de mes déplacements à Rabat et à Casablanca.
#
# lab C
#
# txt2  Les Marocains ont également marqué leur amitié en se manifestant, nombreux, lors de mes déplacements à Rabat et à Casablanca.
#
# tx1t <103:7:C> A travers la personne du président de la République, c'est à l'ensemble du peuple français, et tout particulièrement à vous qui vivez Ici, que s'adressaient ces marques d'attention et de sympathie.
#
# lab C
#
# txt2  A travers la personne du président de la République, c'est à l'ensemble du peuple français, et tout particulièrement à vous qui vivez Ici, que s'adressaient ces marques d'attention et de sympathie.
#
# tx1t <103:8:C> Les entretiens que j'ai eus avec les responsables politiques marocains m'ont permis de faire un large tour d'horizon des relations bilatérales et de réaffirmer notre volonté de demeurer pleinement présents à leurs côtés pour soutenir leurs efforts sur la voie du développement.
#
# lab C
#
# txt2  Les entretiens que j'ai eus avec les responsables politiques marocains m'ont permis de faire un large tour d'horizon des relations bilatérales et de réaffirmer notre volonté de demeurer pleinement présents à leurs côtés pour soutenir leurs efforts sur la voie du développement.
#
# tx1t <103:9:C> Le Maroc, vous le savez, est le premier bénéficiaire de notre action culturelle dans le monde.
#
# lab C
#
# txt2  Le Maroc, vous le savez, est le premier bénéficiaire de notre action culturelle dans le monde.
#
# tx1t <103:10:C> J'ai rappelé les grands axes de notre action dans ce domaine, tels qu'ils ont été définis en accord avec le gouvernement marocain.
#
# lab C
#
# txt2  J'ai rappelé les grands axes de notre action dans ce domaine, tels qu'ils ont été définis en accord avec le gouvernement marocain.
#
# tx1t <103:11:C> Nous sommes convenus d'organiser, en <date>, une "Année du Maroc" en France, série de grandes manifestations culturelles et technologiques, qui permettra de mieux faire connaître le Maroc, ses traditions, mais aussi sa modernité dans toutes les villes de notre pays.
#
# lab C
#
# txt2  Nous sommes convenus d'organiser, en <date>, une "Année du Maroc" en France, série de grandes manifestations culturelles et technologiques, qui permettra de mieux faire connaître le Maroc, ses traditions, mais aussi sa modernité dans toutes les villes de notre pays.
#
# tx1t <103:12:C> En matière économique et financière, nous sommes aussi, par un ensemble de dispositifs d'aides, les premiers partenaires du Royaume.
#
# lab C
#
# txt2  En matière économique et financière, nous sommes aussi, par un ensemble de dispositifs d'aides, les premiers partenaires du Royaume.
#
# tx1t <103:13:C> J'ai fait part de la détermination de la France à maintenir le niveau de son appui financier au Maroc, et à être présente dans le mouvement de solidarité qui se manifeste en faveur du monde rural, durement frappé par la sécheresse.
#
# lab C
#
# txt2  J'ai fait part de la détermination de la France à maintenir le niveau de son appui financier au Maroc, et à être présente dans le mouvement de solidarité qui se manifeste en faveur du monde rural, durement frappé par la sécheresse.
#
# tx1t <103:14:C> Nous saurons marquer notre solidarité alors que le peuple du Maroc est dans la peine.
#
# lab C
#
# txt2  Nous saurons marquer notre solidarité alors que le peuple du Maroc est dans la peine.
#
# tx1t <103:15:C> J'ai annoncé aux autorités marocaines un effort français exceptionnel à cet effet.
#
# lab C
#
# txt2  J'ai annoncé aux autorités marocaines un effort français exceptionnel à cet effet.
#
# tx1t <103:16:C> Je voudrais enfin insister sur notre volonté d'aider le Maroc à trouver toute sa place dans les relations extérieures de l'Union, alors que naîtra à l'automne prochain, lors de la Conférence euro-méditerranéenne de Barcelone, que la présidence française de l'Union a préparée avec ardeur, un vaste espace de coopération politique, commerciale, financière et humaine entre la Méditerranée et l'Europe.
#
# lab C
#
# txt2  Je voudrais enfin insister sur notre volonté d'aider le Maroc à trouver toute sa place dans les relations extérieures de l'Union, alors que naîtra à l'automne prochain, lors de la Conférence euro-méditerranéenne de Barcelone, que la présidence française de l'Union a préparée avec ardeur, un vaste espace de coopération politique, commerciale, financière et humaine entre la Méditerranée et l'Europe.
#
# tx1t <103:17:C> Je sais combien nombre d'entre vous, dirigeants et salariés d'entreprises françaises installées au Maroc et exportant vers l'Europe, Français qui avez consacré votre vie au développement industriel et agricole de ce pays, êtes concernés par ce sujet.
#
# lab C
#
# txt2  Je sais combien nombre d'entre vous, dirigeants et salariés d'entreprises françaises installées au Maroc et exportant vers l'Europe, Français qui avez consacré votre vie au développement industriel et agricole de ce pays, êtes concernés par ce sujet.
#
# tx1t <103:18:C> Mes chers compatriotes, vous représentez Ici les quelques 30 000 Français du Maroc et je voudrais vous remercier d'avoir répondu à mon invitation, en effectuant pour certains le déplacement depuis Agadir, Tanger, Fès, Meknès, Marrakech ou d'autres régions du Royaume.
#
# lab C
#
# txt2  Mes chers compatriotes, vous représentez Ici les quelques 30 000 Français du Maroc et je voudrais vous remercier d'avoir répondu à mon invitation, en effectuant pour certains le déplacement depuis Agadir, Tanger, Fès, Meknès, Marrakech ou d'autres régions du Royaume.
#
# tx1t <103:19:C> Je tiens à vous faire part de ma gratitude et de celle de l'ensemble de la Nation pour le rôle irremplaçable qui ici est le vôtre.
#
# lab C
#
# ...
#
# tx1t <151:44:C> C'est là un objectif ambitieux puisqu'il implique d'augmenter de quelque 20 % le nombre des contrats d'apprentissage et de quelque 30 % le nombre de contrats de qualification.
#
# lab C
#
# txt2  C'est là un objectif ambitieux puisqu'il implique d'augmenter de quelque 20 % le nombre des contrats d'apprentissage et de quelque 30 % le nombre de contrats de qualification.
#
# tx1t <151:45:M> L'Afrique, on le sait, et c'était fort bien dit par le <nom> , est le plus fragile des continents.
#
# lab M
#
# txt2  L'Afrique, on le sait, et c'était fort bien dit par le <nom> , est le plus fragile des continents.
#
# tx1t <151:46:M> Il a été frappé de plein fouet par la crise mondiale.
#
# lab M
#
# txt2  Il a été frappé de plein fouet par la crise mondiale.
#
# tx1t <151:47:M> Dans certains de vos pays, le niveau de vie a baissé de 40 % en dix ans.
#
# lab M
#
# txt2  Dans certains de vos pays, le niveau de vie a baissé de 40 % en dix ans.
#
# tx1t <151:48:M> La chute du cours des matières premières dans des pays sans autres ressources d'exportation, le poids écrasant de la dette, l'explosion démographique, la sécheresse, nous connaissons tous les causes de la stagnation.
#
# lab M
#
# txt2  La chute du cours des matières premières dans des pays sans autres ressources d'exportation, le poids écrasant de la dette, l'explosion démographique, la sécheresse, nous connaissons tous les causes de la stagnation.
#
# tx1t <151:49:M> Ces causes sont réelles, même si elles ne doivent pas servir d'alibi à la mauvaise gestion, à la fuite des capitaux, ou à l'accaparement des richesses par une minorité.
#
# lab M
#
# txt2  Ces causes sont réelles, même si elles ne doivent pas servir d'alibi à la mauvaise gestion, à la fuite des capitaux, ou à l'accaparement des richesses par une minorité.
#
# tx1t <151:50:M> Mais ne nous trompons pas, certains voudraient que l'Afrique fût seule responsable de ses malheurs.
#
# lab M
#
# txt2  Mais ne nous trompons pas, certains voudraient que l'Afrique fût seule responsable de ses malheurs.
#
# tx1t <151:51:M> Ainsi espèrent-ils se faire pardonner leur cécité ou leur égoïsme.
#
# lab M
#
# txt2  Ainsi espèrent-ils se faire pardonner leur cécité ou leur égoïsme.
#
# tx1t <151:52:M> Non, la responsabilité se partage : est-il acceptable qu'au cours de ces dernières années, les flux nets d'aide publique vers l'Afrique soient devenus négatifs, et que certains d'entre eux aient dû rembourser à leurs bailleurs de fonds des montants annuels supérieurs au volume d'aide qu'ils reçoivent ? Vos pays se seraient-ils subitement enrichis pour mériter un tel traitement ? C'est un sujet que j'ai souvent traité avec vous.
#
# lab M
#
# txt2  Non, la responsabilité se partage : est-il acceptable qu'au cours de ces dernières années, les flux nets d'aide publique vers l'Afrique soient devenus négatifs, et que certains d'entre eux aient dû rembourser à leurs bailleurs de fonds des montants annuels supérieurs au volume d'aide qu'ils reçoivent ? Vos pays se seraient-ils subitement enrichis pour mériter un tel traitement ? C'est un sujet que j'ai souvent traité avec vous.
#
# tx1t <151:53:M> La France est souvent intervenue à vos côtés.
#
# lab M
#
# txt2  La France est souvent intervenue à vos côtés.
#
# tx1t <151:54:M> Des mécanismes de régulation internationaux ont été ébauchés ou mis en place depuis les années 70 mais on ne peut pas dire qu'ils aient vraiment fonctionné ou joué en faveur de l'Afrique.
#
# lab M
#
# txt2  Des mécanismes de régulation internationaux ont été ébauchés ou mis en place depuis les années 70 mais on ne peut pas dire qu'ils aient vraiment fonctionné ou joué en faveur de l'Afrique.
#
# tx1t <151:55:M> Echec des accords de produits, pourtant très prometteurs, traitement insuffisant de la dette, stagnation ou recul des flux d'aide.
#
# lab M
#
# txt2  Echec des accords de produits, pourtant très prometteurs, traitement insuffisant de la dette, stagnation ou recul des flux d'aide.
#
# tx1t <151:56:M> Le sort de l'économie africaine a été abandonné au seul marché, donc à la loi du plus fort.
#
# lab M
#
# txt2  Le sort de l'économie africaine a été abandonné au seul marché, donc à la loi du plus fort.
#
# tx1t <151:57:M> Vous, chefs d'Etat et de gouvernement, vous avez des devoirs envers vos peuples.
#
# lab M
#
# txt2  Vous, chefs d'Etat et de gouvernement, vous avez des devoirs envers vos peuples.
#
# tx1t <151:58:M> Il vous faut tout mettre en oeuvre pour parvenir à l'autosuffisance alimentaire qui met à l'abri de bien des malheurs.
#
# lab M
#
# txt2  Il vous faut tout mettre en oeuvre pour parvenir à l'autosuffisance alimentaire qui met à l'abri de bien des malheurs.
#
# tx1t <151:59:M> Quant aux programmes d'éducation primaire et à la mise en oeuvre d'une politique de santé publique, ce sont des priorités à réaliser rapidement.
#
# lab M
#
# txt2  Quant aux programmes d'éducation primaire et à la mise en oeuvre d'une politique de santé publique, ce sont des priorités à réaliser rapidement.
#
# tx1t <151:60:M> Les programmes élaborés par la coopération française prévoient précisément de vous y aider.
#
# lab M
#
# txt2  Les programmes élaborés par la coopération française prévoient précisément de vous y aider.
#
# tx1t <151:61:M> Vous savez bien, vous qui êtes là, que la France, plus que d'autres, et je le dis parce que c'est vrai, a pris sa part d'effort : depuis <date>, nous sommes passés de 0,36 % du PNB à 0,63 %, nous classant au premier rang des pays du G7.
#
# lab M
#
# txt2  Vous savez bien, vous qui êtes là, que la France, plus que d'autres, et je le dis parce que c'est vrai, a pris sa part d'effort : depuis <date>, nous sommes passés de 0,36 % du PNB à 0,63 %, nous classant au premier rang des pays du G7.
#
# tx1t <151:62:M> Notre aide au développement qui, je l'espère, approchera cette année des 0,7 %, retenu comme objectif, a augmenté de 48 % en valeur réelle.
#
# lab M
#
# txt2  Notre aide au développement qui, je l'espère, approchera cette année des 0,7 %, retenu comme objectif, a augmenté de 48 % en valeur réelle.
#
# tx1t <151:63:M> Nous occupons le premier rang mondial pour l'aide à l'Afrique, permettez-moi de le souligner : 3,4 fois plus que la Banque Mondiale, 2,2 fois plus que les Etats-Unis pour <date>.
#
# lab M
#
# txt2  Nous occupons le premier rang mondial pour l'aide à l'Afrique, permettez-moi de le souligner : 3,4 fois plus que la Banque Mondiale, 2,2 fois plus que les Etats-Unis pour <date>.
#
# tx1t <151:64:M> Pour la dette, nous avons procédé en 89, puis en 94, à l'annulation de nos créances publiques sur l'Afrique (27 milliards, puis 25 milliards de francs).
#
# lab M
#
# txt2  Pour la dette, nous avons procédé en 89, puis en 94, à l'annulation de nos créances publiques sur l'Afrique (27 milliards, puis 25 milliards de francs).
#
# tx1t <151:65:M> Je ne dis pas cela pour compter, je ne fais pas l'épicier, je veux simplement que vous sachiez, lorsque des débats s'ouvrent et lorsque des promesses se font, où se trouvent vos amis et où ils se trouveront demain encore.
#
# lab M
#
# txt2  Je ne dis pas cela pour compter, je ne fais pas l'épicier, je veux simplement que vous sachiez, lorsque des débats s'ouvrent et lorsque des promesses se font, où se trouvent vos amis et où ils se trouveront demain encore.
#
# tx1t <151:66:M> Nos efforts auraient pu servir d'exemple aux autres pays créanciers.
#
# lab M
#
# txt2  Nos efforts auraient pu servir d'exemple aux autres pays créanciers.
#
# tx1t <151:67:M> Certains ont suivi, pas tous.
#
# lab M
#
# txt2  Certains ont suivi, pas tous.
#
# tx1t <151:68:C> Je vous le dis, Monsieur le Président, le secteur des travaux publics a vocation à prendre toute sa place, toute sa part dans la réalisation de cet objectif.
#
# lab C
#
# txt2  Je vous le dis, Monsieur le Président, le secteur des travaux publics a vocation à prendre toute sa place, toute sa part dans la réalisation de cet objectif.
#
# tx1t <151:69:C> Car il est conforme aux intérêts des jeunes qui vous font confiance.
#
# lab C
#
# txt2  Car il est conforme aux intérêts des jeunes qui vous font confiance.
#
# tx1t <151:70:C> Il en est capable, comme il l'a montré par le passé avec l'opération que vous aviez engagée et qui fut un succès "avenir jeunes travaux publics".
#
# lab C
#
# txt2  Il en est capable, comme il l'a montré par le passé avec l'opération que vous aviez engagée et qui fut un succès "avenir jeunes travaux publics".
#
# tx1t <151:71:C> Il le montre encore aujourd'hui puisqu'il forme plus de <date> jeunes en alternance, dont 1200 en apprentissage, me disiez-vous récemment.
#
# lab C
#
# txt2  Il le montre encore aujourd'hui puisqu'il forme plus de <date> jeunes en alternance, dont 1200 en apprentissage, me disiez-vous récemment.
#
# tx1t <151:72:C> Le nombre des apprentis formés par les entreprises de travaux publics a plus que doublé depuis <date>.
#
# lab C
#
# txt2  Le nombre des apprentis formés par les entreprises de travaux publics a plus que doublé depuis <date>.
#
# tx1t <151:73:C> Il y a là le signe d'une profession responsable qui veut aller délibérément dans le sens des besoins de la formation des jeunes et naturellement dans l'avenir de son métier.
#
# lab C
#
# txt2  Il y a là le signe d'une profession responsable qui veut aller délibérément dans le sens des besoins de la formation des jeunes et naturellement dans l'avenir de son métier.
#
# tx1t <151:74:C> Je voudrais m'arrêter un instant sur l'accord du 19 septembre dernier signé par les partenaires sociaux de votre branche.
#
# lab C
#
# txt2  Je voudrais m'arrêter un instant sur l'accord du 19 septembre dernier signé par les partenaires sociaux de votre branche.
#
# tx1t <151:75:C> Cet accord a créé un Ordre des tuteurs dans les travaux publics, auquel seront inscrits les professionnels qui ont reçu une formation au tutorat et exercé cette fonction en l'entreprise.
#
# lab C
#
# txt2  Cet accord a créé un Ordre des tuteurs dans les travaux publics, auquel seront inscrits les professionnels qui ont reçu une formation au tutorat et exercé cette fonction en l'entreprise.
#
# tx1t <151:76:C> La création de cet Ordre, qui s'inscrit directement dans la vieille tradition du compagnonnage, qui est une de vos racines, vient récompenser ceux qui, de façon volontaire ou bénévole, apportent - et l'un des jeunes tout à l'heure l'a rappelé - leur expérience et leur savoir-faire aux jeunes dans l'entreprise pour leur donner ce complément indispensable à la réussite dans leur vie professionnelle.
#
# lab C
#
# txt2  La création de cet Ordre, qui s'inscrit directement dans la vieille tradition du compagnonnage, qui est une de vos racines, vient récompenser ceux qui, de façon volontaire ou bénévole, apportent - et l'un des jeunes tout à l'heure l'a rappelé - leur expérience et leur savoir-faire aux jeunes dans l'entreprise pour leur donner ce complément indispensable à la réussite dans leur vie professionnelle.
#
# tx1t <151:77:C> Cela aussi, c'est l'esprit d'équipe, c'est la solidarité qui n'est pas seulement entre jeunes d'une même génération, mais également entre les générations.
#
# lab C
#
# txt2  Cela aussi, c'est l'esprit d'équipe, c'est la solidarité qui n'est pas seulement entre jeunes d'une même génération, mais également entre les générations.
#
# tx1t <151:78:C> Cela représente de la patience, du temps pris sur la vie de famille ou ses occupations, comme l'a souligné le tuteur que nous avons entendu tout à l'heure.
#
# lab C
#
# txt2  Cela représente de la patience, du temps pris sur la vie de famille ou ses occupations, comme l'a souligné le tuteur que nous avons entendu tout à l'heure.
#
# tx1t <151:79:C> Mais c'est un appui précieux pour un jeune qui fait ses premiers pas dans l'entreprise.
#
# lab C
#
# txt2  Mais c'est un appui précieux pour un jeune qui fait ses premiers pas dans l'entreprise.
#
# tx1t <151:80:C> Nous sommes dans un monde où petit à petit, les solidarités se sont dégradées.
#
# lab C
#
# txt2  Nous sommes dans un monde où petit à petit, les solidarités se sont dégradées.
#
# tx1t <151:81:C> Il faut aujourd'hui les reprendre.
#
# lab C
#
# txt2  Il faut aujourd'hui les reprendre.
#
# tx1t <151:82:C> Nous sommes tous solidaires les uns des autres.
#
# lab C
#
# txt2  Nous sommes tous solidaires les uns des autres.
#
# tx1t <151:83:C> C'est la raison pour laquelle, tout ce qui peut recréer ces liens va dans le bon sens.
#
# lab C
#
# txt2  C'est la raison pour laquelle, tout ce qui peut recréer ces liens va dans le bon sens.
#
# tx1t <151:84:C> Pour les jeunes, le système du tutorat, du parrainage, est un système qui est tout à fait vital si l'on veut s'épanouir convenablement dans une profession.
#
# lab C
#
# txt2  Pour les jeunes, le système du tutorat, du parrainage, est un système qui est tout à fait vital si l'on veut s'épanouir convenablement dans une profession.
#
# tx1t <151:85:C> Une formation adaptée à l'emploi, c'est enfin une formation qui accompagne les évolutions de la vie professionnelle.
#
# lab C
#
# txt2  Une formation adaptée à l'emploi, c'est enfin une formation qui accompagne les évolutions de la vie professionnelle.
#
# tx1t <151:86:C> Nous sommes dans un monde où chacun le sait, nous l'avons vu sur les clips et c'est évident, même si je ne veux pas alimenter la querelle entre la pioche et le tunnelier, mais nous sommes dans un monde où les techniques évoluent de plus en plus vite, où les métiers changent, où les restructurations s'accélèrent, la véritable sécurité de l'emploi dans un monde comme le nôtre, c'est la capacité pour chacun de pouvoir passer d'un emploi à un autre.
#
# lab C
#
# txt2  Nous sommes dans un monde où chacun le sait, nous l'avons vu sur les clips et c'est évident, même si je ne veux pas alimenter la querelle entre la pioche et le tunnelier, mais nous sommes dans un monde où les techniques évoluent de plus en plus vite, où les métiers changent, où les restructurations s'accélèrent, la véritable sécurité de l'emploi dans un monde comme le nôtre, c'est la capacité pour chacun de pouvoir passer d'un emploi à un autre.
#
# tx1t <151:87:C> Cela aussi, vous l'avez bien compris dans les travaux publics.
#
# lab C
#
# txt2  Cela aussi, vous l'avez bien compris dans les travaux publics.
#
# tx1t <151:88:C> Les témoignages des jeunes l'ont confirmé.
#
# lab C
#
# txt2  Les témoignages des jeunes l'ont confirmé.
#
# tx1t <151:89:C> Dès le début de votre vie active, vous êtes prêts, vos réactions l'ont montré, à approfondir sans cesse vos compétences et à vous plier aux impératifs de mobilité, géographique et professionnelle, qui caractérisent vos métiers.
#
# lab C
#
# txt2  Dès le début de votre vie active, vous êtes prêts, vos réactions l'ont montré, à approfondir sans cesse vos compétences et à vous plier aux impératifs de mobilité, géographique et professionnelle, qui caractérisent vos métiers.
#
# tx1t <151:90:C> Il faut bouger naturellement dans vos métiers ou alors, il ne fallait pas choisir ce métier.
#
# lab C
#
# txt2
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-c2d2ca13f9cb> in <module>
#       1 fname = "./datasets/AFDpresidentutf8/corpus.tache1.learn.utf8"
# ----> 2 alltxts,alllabs = load_pres(fname)
#
# <ipython-input-21-a29993d60c7b> in load_pres(fname)
#      12         print("lab",lab)
#      13         txt = re.sub(r"<[0-9]*:[0-9]*:.>(.*)","\\1",txt)
# ---> 14         print("txt2",txt)
#      15         if lab.count('M') >0:
#      16             alllabs.append(-1)
#
# /usr/lib/python3/dist-packages/ipykernel/iostream.py in write(self, string)
#     398                 string = string.decode(self.encoding, 'replace')
#     399
# --> 400             is_child = (not self._is_master_process())
#     401             # only touch the buffer in the IO thread to avoid races
#     402             self.pub_thread.schedule(lambda : self._buffer.write(string))
#
# /usr/lib/python3/dist-packages/ipykernel/iostream.py in _is_master_process(self)
#     307                 raise ValueError("echo argument must be a file like object")
#     308
# --> 309     def _is_master_process(self):
#     310         return os.getpid() == self._master_pid
#     311
#
# KeyboardInterrupt:

# %%
print(len(alltxts),len(alllabs))
print(alltxts[0])
print(alllabs[0])
print(alltxts[-1])
print(alllabs[-1])
# Out:
# 57413 57413
#  Quand je dis chers amis, il ne s'agit pas là d'une formule diplomatique, mais de l'expression de ce que je ressens.
#
# 1
#  Je compte sur vous.
# 1

# %% [markdown]
# # Données classification de sentiments (films)

# %%
def load_movies(path2data): # 1 classe par répertoire
    alltxts = [] # init vide
    labs = []
    cpt = 0
    for cl in os.listdir(path2data): # parcours des fichiers d'un répertoire
        for f in os.listdir(path2data+cl):
            txt = open(path2data+cl+'/'+f).read()
            alltxts.append(txt)
            labs.append(cpt)
        cpt+=1 # chg répertoire = cht classe
        
    return alltxts,labs

# %%
path = "./datasets/movies/movies1000/"

alltxts,alllabs = load_movies(path)

# %%
print(len(alltxts),len(alllabs))
print(alltxts[0])
print(alllabs[0])
print(alltxts[-1])
print(alllabs[-1])
# Out:
# 2000 2000
# plot : jet li is a chinese cop asked to help some french policemen nab a bad guy .
# but one thing leads to another , and the next thing you know , li's being chased by the same french cops with whom he was supposed to be working .
# a lot of ass-kicking , face-whippings , gun fights and . . . okay , a little more ass-kicking ensues .
# critique : very cool !
# now here's a movie that gives you exactly what you're looking for , if what you're looking for is kickass action , a palpable good cop/bad cop story line , some hardcore stunts and jet li slam-dunking everyone in sight !
# the film also moves fast ( a mere 95 minutes ) , develops a certain " cute " chemistry between fonda and li , has nice surroundings ( paris , baby ! ) and gives us one of the best bad guys that i've seen all year .
# tcheky karyo is the devil incarnate in this film .
# he is pure evil .
# they should have called this movie bad lieutenant 2 as keitel has nothing on this man .
# what a great , great monster !
# my favorite line of tcheky's was when li was explaining the whole " kiss of the dragon " thing to him and he cut him off by saying " kiss my ass ! "
# pure action movie poetry .
# anyway , other than him , jet li also handled his " acting " pretty well in this film , with very little real dialogue to say , but enough to make us believe his character .
# actually , just looking into the man's eyes generally tells you a lot .
# fonda was also pretty good , despite playing one of the most trashy and abused women that i have seen in quite some time , but i still felt kinda bad for her , so i guess she did her job okay .
# but in the end , nobody goes to see this kind of movie for oscar performances .
# we go to see jet li movies because we want to see jet li kicking a lot of ass from side to side , and this film delivers gangbusters on that front .
# and yes . . . they have no wire-fu in this movie . . . i
# say again . . . no
# wire-work , no bullshit stunts with li floating around in mid-air for over a minute .
# it's all straight action , fist to fist , boot to face and all around cool stunts .
# if that's what you're looking for , i don't see how you will be disappointed with this film .
# yes , it's not very original in plot ( just take luc besson's own la femme nikita and mix in plenty of his own the professional et voila ! ) , does have an annoying hip-hoppy soundtrack that just got on my nerves after a while ( i also would have gotten rid of the whole acupuncture thang . . . ) and will have anyone not willing to restrain their disbelief , rolling their eyes all over the place .
# but was i entertained ?
# thoroughly .
# does the film feature more gunplay , martial arts and over-the-top kills that most recent action flicks ?
# yes , again .
# does this sound interesting to you ?
# well , the answer to that question is entirely up to you .
# one thing that i would definitely recommend is , as jet li pointed out himself on his website , that you leave the kids at home for this one .
# in fact , you might even wanna leave yourself if you can't handle the more violent of sequences .
# all in all , a rippin' , roarin' fun time !
# where's joblo coming from ?
# black mask ( 5/10 ) - blade ( 7/10 ) - la femme nikita ( 8/10 ) - lethal weapon 4 ( 7/10 ) - the matrix ( 8/10 ) - the professional ( 9/10 ) - romeo must die ( 3/10 ) - rush hour ( 7/10 ) - shanghai noon ( 6/10 )
#
# 0
# my first exposure to the nightmare on elm street series of films was not this one , but in fact the third installment ( it was the first to gain a national theatrical release ) .
# i didn't see the first film until much later .
# so looking back , the original didn't hold a lot of great memories for me , since i didn't think too much of it when i initially saw it .
# watching it now for a second time confirmed that it's an overrated horror film that ultimately makes no sense whatsoever .
# you all know the story by now : child murderer freddy krueger ( robert englund ) returns from the grave by haunting the dreams of the children of those who burned him alive years before .
# this first installment does an adequate job with it's low budget , but there's some absurd dialogue and conceptual problems with the story .
# plus the movie's ending ( understandably the result of the studio wanting the end of the film to have a " hook " for a sequel ) renders the rest of the film pointless .
# and does anyone understand what happens to nancy's mother at the end of this film ?
# don't get me wrong though . . .
# it's not as if a new generation of horror films have spurned me away from the classics .
# most horror movies released today are just as inane as this film is .
# horror is a difficult genre to pull off credibly , and a nightmare on elm street just doesn't cut it .
# a nightmare on elm street is available on dvd from new line home video .
# it is available both as a single disc and as part of the nightmare on elm street collection box set .
# the film is presented in both pan and scan and it's original theatrical aspect ratio of 1 . 78 : 1 ( although on the disc that comes in the box set , only a widescreen transfer is provided ) .
# the film has been digitally remastered and includes two options for audio : a mono mix and a new dolby digital 5 . 1 mix .
# also included on the dvd is a full-length audio commentary track with writer/director wes craven , stars john saxon and heather langenkamp , and the film's director of photography .
# other extras include the " jump to a nightmare " feature ( i'm sure you can figure that one out ) , the usual cast and crew bios ( which are from the film's original press release kit , and notably leave out robert englund and johnny depp ! ) , and the film's original theatrical trailer .
# some dvd-rom features are also included , but since i don't have dvd-rom capabilities i can't really get into that .
# the commentary track is entertaining and informative , but nothing spectacular .
# the first thing of note is that it's the same commentary track that was on the special edition laserdisc from a few years ago .
# i'm not saying that's a negative thing , just pointing it out .
# everyone seems enthusiastic about being there , with the possible exception of john saxon , who just doesn't say much at all .
# most of the time you'll forget he's even there .
# everyone else talks really quietly though for some reason , as if because they're commenting on a scary movie that they need to stay as quiet as possible .
# the bonus disc with the boxed set called the nightmare series encyclopedia features about 45 minutes worth of interviews relating to the first film of the series .
# also included is the original theatrical trailer and two alternate endings to the film . . .
# however you can only access one easily .
# the other is hidden in what's called " the labyrinth " , which might possibly be the most annoying feature of a dvd ever created .
# basically , it's an interactive game of sorts where you wander through different nightmare locations looking at objects which give you access to extra little snippets of footage , interviews , etc . somewhere in the labyrinth is the second alternate ending to the film .
# finding it though is both a chore and a bore .
# [r]
#
# 1

# %% [markdown]
# # A) Transformation paramétrique du texte (pre-traitements)
#
# Vous devez tester, par exemple, les cas suivants:
# - transformation en minuscule ou pas
# - suppression de la ponctuation
# - transformation des mots entièrement en majuscule en marqueurs spécifiques
# - suppression des chiffres ou pas
# - conservation d'une partie du texte seulement (seulement la première ligne = titre, seulement la dernière ligne = résumé, ...)
# - stemming
# - ...
#
#
# Vérifier systématiquement sur un exemple ou deux le bon fonctionnement des méthodes sur deux documents (au moins un de chaque classe).

# %% [markdown]
# # B) Extraction du vocabulaire (BoW)
#
# - **Exploration préliminaire des jeux de données**
#     - Quelle est la taille d'origine du vocabulaire?
#     - Que reste-t-il si on ne garde que les 100 mots les plus fréquents? [word cloud]
#     - Quels sont les 100 mots dont la fréquence documentaire est la plus grande? [word cloud]
#     - Quels sont les 100 mots les plus discriminants au sens de odds ratio? [word cloud]
#     - Quelle est la distribution d'apparition des mots (Zipf)
#     - Quels sont les 100 bigrammes/trigrammes les plus fréquents?
#
# - **Variantes de BoW**
#     - TF-IDF
#     - Réduire la taille du vocabulaire (min_df, max_df, max_features)
#     - BoW binaire
#     - Bi-grams, tri-grams
#     - **Quelles performances attendre ? Quels sont les avantages et les inconvénients des ces variantes?**

# %% [markdown]
# # C) Modèles de Machine Learning

# %% [markdown]
# ## 1) Métriques d'évaluation
#
# Il faudra utiliser des métriques d'évaluation pertinentes suivant la tâche et l'équilibrage des données :
# - Accuracy
# - Courbe ROC, AUC, F1-score

# %% [markdown]
# ## 2) Variantes sur les stratégies d'entraînement
#
# - **Sur-apprentissage**. Les techniques sur lesquelles nous travaillons étant sujettes au sur-apprentissage: trouver le paramètre de régularisation dans la documentation et optimiser ce paramètre au sens de la métrique qui vous semble la plus appropriée (cf question précédente).
#
#  <br>
# - **Equilibrage des données**. Un problème reconnu comme dur dans la communauté est celui de l'équilibrage des classes (*balance* en anglais). Que faire si les données sont à 80, 90 ou 99% dans une des classes?
# Le problème est dur mais fréquent; les solutions sont multiples mais on peut isoler 3 grandes familles de solution.
#
# 1. Ré-équilibrer le jeu de données: supprimer des données dans la classe majoritaire et/ou sur-échantilloner la classe minoritaire.<BR>
#    $\Rightarrow$ A vous de jouer pour cette technique
# 1. Changer la formulation de la fonction de coût pour pénaliser plus les erreurs dans la classe minoritaire:
# soit une fonction $\Delta$ mesurant les écarts entre $f(x_i)$ et $y_i$
# $$C = \sum_i  \alpha_i \Delta(f(x_i),y_i), \qquad \alpha_i = \left\{
# \begin{array}{ll}
# 1 & \text{si } y_i \in \text{classe majoritaire}\\
# B>1 & \text{si } y_i \in \text{classe minoritaire}\\
# \end{array} \right.$$
# <BR>
#    $\Rightarrow$ Les SVM et d'autres approches sklearn possèdent des arguments pour régler $B$ ou $1/B$... Ces arguments sont utiles mais pas toujours suffisant.
# 1. Courbe ROC et modification du biais. Une fois la fonction $\hat y = f(x)$ apprise, il est possible de la *bidouiller* a posteriori: si toutes les prédictions $\hat y$ sont dans une classe, on va introduire $b$ dans $\hat y = f(x) + b$ et le faire varier jusqu'à ce qu'un des points change de classe. On peut ensuite aller de plus en plus loin.
# Le calcul de l'ensemble des scores associés à cette approche mène directement à la courbe ROC.
#
# **Note:** certains classifieurs sont intrinsèquement plus résistante au problème d'équilibrage, c'est par exemple le cas des techniques de gradient boosting que vous verrez l'an prochain.

# %% [markdown]
# ## 3) Post-processing sur les données Président
#
# Pour la tâche de reconnaissance de locuteur, des phrases successives sont souvent associés à un même locuteur. Voir par exemples les 100 premiers labels de la base d'apprentissage.

# %%
fname = "./datasets/AFDpresidentutf8/corpus.tache1.learn.utf8"
alltxts,alllabs = load_pres(fname)

plt.figure()
plt.plot(list(range(len(alllabs[0:100]))),alllabs[0:100])

# %% [markdown]
# **Une méthode de post-traitement pour améliorer les résultats consistent à lisser les résultats de la prédictions d'une phrases par les prédictions voisines, en utilisant par exemple une convolution par une filtre Gaussien. Compléter la fonction ci-dessous et tester l'impact de ce lissage sur les performances.**

# %%
def gaussian_smoothing(pred, size):
     # LISSAGE par un filtre Gaussien de taille size - vous pouvez utiliser np.convolve 
    return 0

# %% [markdown]
# ## 4) Estimer les performances de généralisation d'une méthodes
# **Ce sera l'enjeu principal du projet : vous disposez d'un ensemble de données, et vous évaluerez les performances sur un ensemble de test auquel vous n'avez pas accès. Il faut donc être capable d'estimer les performances de généralisation du modèles à partir des données d'entraînement.**

# %% [markdown]
# Avant de lancer de grandes expériences, il faut se construire une base de travail solide en étudiant les questions suivantes:
#
# - Combien de temps ça prend d'apprendre un classifieur NB/SVM/RegLog sur ces données en fonction de la taille du vocabulaire?
# - La validation croisée est-elle nécessaire? Est ce qu'on obtient les mêmes résultats avec un simple *split*?
# - La validation croisée est-elle stable? A partir de combien de fold (travailler avec différentes graines aléatoires et faire des statistiques basiques)?
